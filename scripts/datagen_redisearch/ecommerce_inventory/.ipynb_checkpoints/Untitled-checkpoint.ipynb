# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv('1M-ecommerce-inventory.redisearch.commands.BENCH.csv', sep=';' )

# %%
df.sample(10)
# Out:
#        UPDATE,U1,2,FT.ADD,inventory,inventory-FR_1817_65abde54072e40569be4a324211e1362,1.0,REPLACE,PARTIAL,FIELDS,market,FR,nodeId,1817,nodeType,store,availableToSource,false,standardAvailableToPromise,true
# 45276   UPDATE,U1,2,FT.ADD,inventory,inventory-US_2172...
# 749765  UPDATE,U1,2,FT.ADD,inventory,inventory-US_2950...
# 632901  UPDATE,U1,2,FT.ADD,inventory,inventory-IL_276_...
# 366596  UPDATE,U1,2,FT.ADD,inventory,inventory-US_1829...
# 780131  UPDATE,U1,2,FT.ADD,inventory,inventory-US_3277...
# 348718  READ,R1,1,FT.AGGREGATE,inventory,@market:{US} ...
# 199094  UPDATE,U1,2,FT.ADD,inventory,inventory-US_4121...
# 735106  UPDATE,U1,2,FT.ADD,inventory,inventory-US_2229...
# 945917  UPDATE,U1,2,FT.ADD,inventory,inventory-US_3722...
# 511408  UPDATE,U1,2,FT.ADD,inventory,inventory-US_2334...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000049 entries, 0 to 1000048
# Data columns (total 61 columns):
#  #   Column                                           Non-Null Count    Dtype
# ---  ------                                           --------------    -----
#  0   SETUP_WRITE                                      1000049 non-null  object
#  1   S1                                               1000049 non-null  object
#  2   2                                                1000049 non-null  int64
#  3   FT.ADD                                           1000049 non-null  object
#  4   inventory                                        1000049 non-null  object
#  5   inventory-US_1_6ace7bfa817d4b3cad8b6f2ef14b393f  1000049 non-null  object
#  6   1.0                                              1000049 non-null  float64
#  7   REPLACE                                          1000049 non-null  object
#  8   FIELDS                                           1000049 non-null  object
#  9   market                                           1000049 non-null  object
#  10  US                                               1000049 non-null  object
#  11  nodeId                                           1000049 non-null  object
#  12  1                                                1000049 non-null  int64
#  13  skuId                                            1000049 non-null  object
#  14  eac7efa5dbd3d667f26eb3d3ab504464                 1000049 non-null  object
#  15  onhand                                           1000049 non-null  object
#  16  16890                                            1000049 non-null  int64
#  17  onhandLastUpdatedTimestamp                       1000049 non-null  object
#  18  1729268168                                       1000049 non-null  int64
#  19  allocated                                        1000049 non-null  object
#  20  38575                                            1000049 non-null  int64
#  21  allocatedLastUpdatedTimestamp                    1000049 non-null  object
#  22  1729286638                                       1000049 non-null  int64
#  23  reserved                                         1000049 non-null  object
#  24  28421                                            1000049 non-null  int64
#  25  reservedLastUpdatedTimestamp                     1000049 non-null  object
#  26  1729296972                                       1000049 non-null  int64
#  27  storeAllocated                                   1000049 non-null  object
#  28  33963                                            1000049 non-null  int64
#  29  storeAllocatedLastUpdatedTimestamp               1000049 non-null  object
#  30  1729312781                                       1000049 non-null  int64
#  31  transferAllocated                                1000049 non-null  object
#  32  60032                                            1000049 non-null  int64
#  33  transferAllocatedLastUpdatedTimestamp            1000049 non-null  object
#  34  1729337607                                       1000049 non-null  int64
#  35  storeReserved                                    1000049 non-null  object
#  36  62826                                            1000049 non-null  int64
#  37  storeReservedLastUpdatedTimestamp                1000049 non-null  object
#  38  1729311764                                       1000049 non-null  int64
#  39  confirmedQuantity                                1000049 non-null  object
#  40  8511                                             1000049 non-null  int64
#  41  standardSafetyStock                              1000049 non-null  object
#  42  2722                                             1000049 non-null  int64
#  43  bopisSafetyStock                                 1000049 non-null  object
#  44  10756                                            1000049 non-null  int64
#  45  virtualHold                                      1000049 non-null  object
#  46  19747                                            1000049 non-null  int64
#  47  availableToSource                                1000049 non-null  object
#  48  true                                             1000049 non-null  bool
#  49  standardAvailableToPromise                       1000049 non-null  object
#  50  true.1                                           1000049 non-null  bool
#  51  bopisAvailableToPromise                          1000049 non-null  object
#  52  true.2                                           1000049 non-null  bool
#  53  nodeType                                         1000049 non-null  object
#  54  store                                            1000049 non-null  object
#  55  brand                                            1000049 non-null  object
#  56  Hornby                                           999349 non-null   object
#  57  onHold                                           1000049 non-null  object
#  58  false                                            1000049 non-null  bool
#  59  exclusionType                                    1000049 non-null  object
#  60  false.1                                          1000049 non-null  bool
# dtypes: bool(5), float64(1), int64(18), object(37)
# memory usage: 432.0+ MB

# %% [markdown]
# # First try

# %%
df = pd.read_csv("./../../../scripts/usecases/ecommerce/amazon_co-ecommerce_sample.csv")

# %%
df.head(3)
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# 2                     2 new                17                           2.0
#
#   average_review_rating                   amazon_category_and_sub_category  \
# 0    4.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 1    4.5 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 2    3.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Classic-Train-Lights-B...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
#
#                                              sellers
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...

# %%
df.columns
# Out:
# Index(['uniq_id', 'product_name', 'manufacturer', 'price',
#        'number_available_in_stock', 'number_of_reviews',
#        'number_of_answered_questions', 'average_review_rating',
#        'amazon_category_and_sub_category',
#        'customers_who_bought_this_item_also_bought', 'description',
#        'product_information', 'product_description',
#        'items_customers_buy_after_viewing_this_item',
#        'customer_questions_and_answers', 'customer_reviews', 'sellers'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   uniq_id                                      10000 non-null  object
#  1   product_name                                 10000 non-null  object
#  2   manufacturer                                 9993 non-null   object
#  3   price                                        8565 non-null   object
#  4   number_available_in_stock                    7500 non-null   object
#  5   number_of_reviews                            9982 non-null   object
#  6   number_of_answered_questions                 9235 non-null   float64
#  7   average_review_rating                        9982 non-null   object
#  8   amazon_category_and_sub_category             9310 non-null   object
#  9   customers_who_bought_this_item_also_bought   8938 non-null   object
#  10  description                                  9349 non-null   object
#  11  product_information                          9942 non-null   object
#  12  product_description                          9349 non-null   object
#  13  items_customers_buy_after_viewing_this_item  6935 non-null   object
#  14  customer_questions_and_answers               914 non-null    object
#  15  customer_reviews                             9979 non-null   object
#  16  sellers                                      6918 non-null   object
# dtypes: float64(1), object(16)
# memory usage: 1.3+ MB

# %%
import random

# Function to generate random prices as floats
def generate_random_price():
    """
    Generates a random price as a float between 1 and 100.
    
    :return: A float representing a random price.
    """
    return round(random.uniform(1, 100), 2)

df['price_rand'] = [generate_random_price() for _ in range(len(df))]

def generate_random_stock():
    return random.randint(1, 100)

# Add a new column with random stock numbers
df['stock'] = [generate_random_stock() for _ in range(len(df))]

# %%
df.head(3)
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# 2                     2 new                17                           2.0
#
#   average_review_rating                   amazon_category_and_sub_category  \
# 0    4.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 1    4.5 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 2    3.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Classic-Train-Lights-B...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
#
#                                              sellers  price_rand  stock
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...       90.12     91
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...       87.35     59
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...       55.80     64

# %%
#df['price'] = df['price'].str.replace('£', '')

# %%
df.drop(columns=['price', 'number_available_in_stock'],inplace=True)
df
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 3     e12b92dbb8eaee78b22965d2a9bbbd9f
# 4     e33a9adeed5f36840ccc227db4682a36
# ...                                ...
# 9995  44d6967f083825a5de36ad4865a65bcd
# 9996  08f0747b6fc6687215ffb994c3a6fb32
# 9997  bf6cc073f8f24e6e338190fa16f6ee9d
# 9998  cd783d0b8b44e631b9788b203eaaefae
# 9999  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  manufacturer number_of_reviews  number_of_answered_questions  \
# 0                      Hornby                15                           1.0
# 1                   FunkyBuys                 2                           1.0
# 2                         ccf                17                           2.0
# 3                      Hornby                 1                           2.0
# 4                      Hornby                 3                           2.0
# ...                       ...               ...                           ...
# 9995                   Mattel                 3                           3.0
# 9996                Star Wars                 1                           3.0
# 9997  Olde Scotland Yard Ltd.                 1                           3.0
# 9998                DC Comics                 1                           3.0
# 9999                   Bandai                11                           3.0
#
#      average_review_rating                   amazon_category_and_sub_category  \
# 0       4.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 1       4.5 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 2       3.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 3       5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 4       4.7 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# ...                    ...                                                ...
# 9995    5.0 out of 5 stars  Hobbies > Collectible Figures & Memorabilia > ...
# 9996    4.0 out of 5 stars             Characters & Brands > Star Wars > Toys
# 9997    5.0 out of 5 stars  Novelty & Special Use > Novelty > Accessories ...
# 9998    5.0 out of 5 stars  Hobbies > Collectible Figures & Memorabilia > ...
# 9999    4.5 out of 5 stars             Characters & Brands > Star Wars > Toys
#
#              customers_who_bought_this_item_also_bought  \
# 0     http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1     http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2     http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                                   NaN
# 4     http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
# ...                                                 ...
# 9995  http://www.amazon.co.uk/Batman-1966-Series-Act...
# 9996  http://www.amazon.co.uk/Storm-Trooper-Costume-...
# 9997                                                NaN
# 9998                                                NaN
# 9999  http://www.amazon.co.uk/Bandai-Star-Wars-Fight...
#
#                                             description  \
# 0     Product Description Hornby 2014 Catalogue Box ...
# 1     Size Name:Large FunkyBuys® Large Christmas Hol...
# 2     BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3     Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4     Product Description Hornby RailRoad 0-4-0 Gild...
# ...                                                 ...
# 9995  DC 66 Batman Classic TV Series 6 Inch Riddler ...
# 9996                                                NaN
# 9997  *Includes 1x Badge with holder and chain *High...
# 9998  Designed by Ed BenesIt's here - the third seri...
# 9999                                                NaN
#
#                                     product_information  \
# 0     Technical Details Item Weight640 g Product Dim...
# 1     Technical Details Manufacturer recommended age...
# 2     Technical Details Manufacturer recommended age...
# 3     Technical Details Item Weight259 g Product Dim...
# 4     Technical Details Item Weight159 g Product Dim...
# ...                                                 ...
# 9995  Technical Details Item Weight136 g Product Dim...
# 9996  Technical Details    Additional Information AS...
# 9997  Technical Details Item Weight159 g Product Dim...
# 9998  Technical Details Item Weight181 g Product Dim...
# 9999  Technical Details Item Weight299 g Product Dim...
#
#                                     product_description  \
# 0     Product Description Hornby 2014 Catalogue Box ...
# 1     Size Name:Large FunkyBuys® Large Christmas Hol...
# 2     BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3     Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4     Product Description Hornby RailRoad 0-4-0 Gild...
# ...                                                 ...
# 9995  DC 66 Batman Classic TV Series 6 Inch Riddler ...
# 9996                                                NaN
# 9997  *Includes 1x Badge with holder and chain *High...
# 9998  Designed by Ed BenesIt's here - the third seri...
# 9999                                                NaN
#
#             items_customers_buy_after_viewing_this_item  \
# 0     http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1     http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2     http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                                   NaN
# 4     http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
# ...                                                 ...
# 9995                                                NaN
# 9996  http://www.amazon.co.uk/Storm-Trooper-Costume-...
# 9997  http://www.amazon.co.uk/Olde-Scotland-Yard-Ltd...
# 9998                                                NaN
# 9999                                                NaN
#
#                          customer_questions_and_answers  \
# 0     Does this catalogue detail all the previous Ho...
# 1     can you turn off sounds // hi no you cant turn...
# 2     What is the gauge of the track // Hi Paul.Trut...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                        customer_reviews  \
# 0     Worth Buying For The Pictures Alone (As Ever) ...
# 1     Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2     **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3     I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4     Birthday present // 5.0 // 14 April 2014 // By...
# ...                                                 ...
# 9995  Realistic // 5.0 // 31 Mar. 2014 // By\n    \n...
# 9996  ... what I see my grandson us going to have fu...
# 9997  Five Stars // 5.0 // 18 Dec. 2015 // By\n    \...
# 9998  The best sculpt in a while // 5.0 // 13 May 20...
# 9999  Gold leader // 5.0 // 31 Aug. 2015 // By\n    ...
#
#                                                 sellers  price_rand  stock
# 0     {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...       90.12     91
# 1     {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...       87.35     59
# 2     {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...       55.80     64
# 3                                                   NaN       41.79      2
# 4                                                   NaN       76.79     62
# ...                                                 ...         ...    ...
# 9995  {"seller"=>[{"Seller_name_1"=>"Star Action Fig...       32.05      2
# 9996                                                NaN       72.57      6
# 9997  {"seller"=>[{"Seller_name_1"=>"YUK", "Seller_p...       18.10     48
# 9998  {"seller"=>[{"Seller_name_1"=>"Smaller World F...       16.43     43
# 9999                                                NaN       31.52     29
#
# [10000 rows x 17 columns]

# %%
import pandas as pd
import random
from faker import Faker
import uuid

fake = Faker()

def expand_ecommerce_data(df, target_size):
    """
    Expands an e-commerce dataframe to the specified target size by duplicating and modifying existing rows.
    Ensures unique IDs for new rows.
    
    Parameters:
    df (pd.DataFrame): Original e-commerce dataframe (10,000 rows).
    target_size (int): Target number of rows in the expanded dataframe.
    
    Returns:
    pd.DataFrame: Expanded dataframe with N rows.
    """
    
    current_size = len(df)
    
    if target_size <= current_size:
        return df
    
    # Calculate how many additional rows are needed
    additional_rows_needed = target_size - current_size

    # Repeat rows and shuffle them
    additional_data = df.sample(additional_rows_needed, replace=True).reset_index(drop=True)

    # Function to modify price keeping £ structure
    def modify_price(price):
        new_price_value = round(price * random.uniform(0.9, 1.1), 2)  # Modify price by ±10%
        return new_price_value  # Format back to string with £

    # Generate new unique IDs for additional data
    additional_data['uniq_id'] = [str(uuid.uuid4()) for _ in range(additional_rows_needed)]
    
    # Introduce small variations in price, stock, and product name
    additional_data['price_rand'] = additional_data['price_rand'].apply(modify_price)
    additional_data['stock'] = additional_data['stock'].apply(
        lambda x: max(0, int(x * random.uniform(0.8, 1.2))))
    additional_data['product_name'] = additional_data['product_name'].apply(lambda x: x + ' ' + fake.word())
    
    # Concatenate the original data with the additional data
    expanded_df = pd.concat([df, additional_data], ignore_index=True)

    return expanded_df

# Example usage
# Assuming `ecommerce_df` is your original dataframe with 10,000 rows
# expanded_df = expand_ecommerce_data(ecommerce_df, 50000)
# print(expanded_df.shape)  # Should print (50000, <number_of_columns>)

# %%
df_expanded = expand_ecommerce_data(df=df, target_size=300000)

# %%
df_expanded
# Out:
#                                      uniq_id  \
# 0           eac7efa5dbd3d667f26eb3d3ab504464
# 1           b17540ef7e86e461d37f3ae58b7b72ac
# 2           348f344247b0c1a935b1223072ef9d8a
# 3           e12b92dbb8eaee78b22965d2a9bbbd9f
# 4           e33a9adeed5f36840ccc227db4682a36
# ...                                      ...
# 299995  c1ba565c-036f-4194-ac65-f43d8e3c3148
# 299996  f99d6621-88a9-4eb5-a926-2045f538a17f
# 299997  aa16a0ca-80bd-484f-a09a-24b5043a2792
# 299998  dac19457-d95e-4bbf-ab2c-441388875fda
# 299999  d14cc719-fef5-48f8-ae68-3df9fc355d57
#
#                                              product_name    manufacturer  \
# 0                                   Hornby 2014 Catalogue          Hornby
# 1       FunkyBuys® Large Christmas Holiday Express Fes...       FunkyBuys
# 2       CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...             ccf
# 3          HORNBY Coach R4410A BR Hawksworth Corridor 3rd          Hornby
# 4       Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...          Hornby
# ...                                                   ...             ...
# 299995             Jeff Dunham Achmed Window Cling career     Juff Dunham
# 299996  Ultra Pro SLEEVES MTG Mana 4 Planeswalkers Cha...       Ultra Pro
# 299997  50th Gold Anniversary Giant Gold & White Banne...  Creative Party
# 299998  GoTeck 8143 RC Electric Large On Off Switch w ...             BSP
# 299999      Viessmann 64706 H0 6pc set Park lamps between       Viessmann
#
#        number_of_reviews  number_of_answered_questions average_review_rating  \
# 0                     15                           1.0    4.9 out of 5 stars
# 1                      2                           1.0    4.5 out of 5 stars
# 2                     17                           2.0    3.9 out of 5 stars
# 3                      1                           2.0    5.0 out of 5 stars
# 4                      3                           2.0    4.7 out of 5 stars
# ...                  ...                           ...                   ...
# 299995                 2                           1.0    5.0 out of 5 stars
# 299996                 2                           3.0    5.0 out of 5 stars
# 299997                 1                           1.0    5.0 out of 5 stars
# 299998                 1                           1.0    5.0 out of 5 stars
# 299999                 1                           1.0    5.0 out of 5 stars
#
#                          amazon_category_and_sub_category  \
# 0       Hobbies > Model Trains & Railway Sets > Rail V...
# 1       Hobbies > Model Trains & Railway Sets > Rail V...
# 2       Hobbies > Model Trains & Railway Sets > Rail V...
# 3       Hobbies > Model Trains & Railway Sets > Rail V...
# 4       Hobbies > Model Trains & Railway Sets > Rail V...
# ...                                                   ...
# 299995     Figures & Playsets > Science Fiction & Fantasy
# 299996  Hobbies > Trading Cards & Accessories > Storag...
# 299997  Party Supplies > Banners, Stickers & Confetti ...
# 299998  Hobbies > Remote Controlled Devices > Parts & ...
# 299999  Hobbies > Model Trains & Railway Sets > Lighti...
#
#                customers_who_bought_this_item_also_bought  \
# 0       http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1       http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2       http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                                     NaN
# 4       http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
# ...                                                   ...
# 299995  http://www.amazon.co.uk/JEFF-DUNHAM-All-Over-M...
# 299996  http://www.amazon.co.uk/Ultra-Pro-Collectors |...
# 299997  http://www.amazon.co.uk/50th-Anniversary | htt...
# 299998  http://www.amazon.co.uk/Toys-BSD-Switch-Receiv...
# 299999  http://www.amazon.co.uk/Viessmann-64906-6pc-wh...
#
#                                               description  \
# 0       Product Description Hornby 2014 Catalogue Box ...
# 1       Size Name:Large FunkyBuys® Large Christmas Hol...
# 2       BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3       Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4       Product Description Hornby RailRoad 0-4-0 Gild...
# ...                                                   ...
# 299995         Neca Jeff Dunham Achmed Window Cling Plush
# 299996  Product Description SLEEVES MTG Mana 4 Planesw...
# 299997                                                NaN
# 299998  Large On Off Switch Futaba Connectors with LED...
# 299999  Suitable for the following scale(s): N ScaleSe...
#
#                                       product_information  \
# 0       Technical Details Item Weight640 g Product Dim...
# 1       Technical Details Manufacturer recommended age...
# 2       Technical Details Manufacturer recommended age...
# 3       Technical Details Item Weight259 g Product Dim...
# 4       Technical Details Item Weight159 g Product Dim...
# ...                                                   ...
# 299995  Technical Details Item Weight45 g Product Dime...
# 299996  Technical Details Item Weight91 g Product Dime...
# 299997  Technical Details Manufacturer recommended age...
# 299998  Technical Details Manufacturer recommended age...
# 299999  Technical Details Item Weight9 g Product Dimen...
#
#                                       product_description  \
# 0       Product Description Hornby 2014 Catalogue Box ...
# 1       Size Name:Large FunkyBuys® Large Christmas Hol...
# 2       BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3       Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4       Product Description Hornby RailRoad 0-4-0 Gild...
# ...                                                   ...
# 299995         Neca Jeff Dunham Achmed Window Cling Plush
# 299996  Product Description SLEEVES MTG Mana 4 Planesw...
# 299997                                                NaN
# 299998  Large On Off Switch Futaba Connectors with LED...
# 299999  Suitable for the following scale(s): N ScaleSe...
#
#               items_customers_buy_after_viewing_this_item  \
# 0       http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1       http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2       http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                                     NaN
# 4       http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
# ...                                                   ...
# 299995  http://www.amazon.co.uk/Neca-Dunham-Walter-Tal...
# 299996  http://www.amazon.co.uk/Black-Trading-Cards-St...
# 299997                                                NaN
# 299998  http://www.amazon.co.uk/Toys-BSD-Switch-Receiv...
# 299999                                                NaN
#
#                            customer_questions_and_answers  \
# 0       Does this catalogue detail all the previous Ho...
# 1       can you turn off sounds // hi no you cant turn...
# 2       What is the gauge of the track // Hi Paul.Trut...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 299995                                                NaN
# 299996                                                NaN
# 299997                                                NaN
# 299998                                                NaN
# 299999                                                NaN
#
#                                          customer_reviews  \
# 0       Worth Buying For The Pictures Alone (As Ever) ...
# 1       Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2       **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3       I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4       Birthday present // 5.0 // 14 April 2014 // By...
# ...                                                   ...
# 299995  Great little pressie // 5.0 // 9 Dec. 2014 // ...
# 299996  Ultra Pro Deck Protectors = Quality // 5.0 // ...
# 299997  Just what i wanted // 5.0 // 21 Jan. 2015 // B...
# 299998  Five Stars // 5.0 // 27 Aug. 2015 // By\n    \...
# 299999  Viessmann model railway street lights // 5.0 /...
#
#                                                   sellers  price_rand  stock
# 0       {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...       90.12     91
# 1       {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...       87.35     59
# 2       {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...       55.80     64
# 3                                                     NaN       41.79      2
# 4                                                     NaN       76.79     62
# ...                                                   ...         ...    ...
# 299995  {"seller"=>[{"Seller_name_1"=>"Toy Zany", "Sel...       57.08     50
# 299996                                                NaN       85.77     83
# 299997                                                NaN       60.06     45
# 299998  {"seller"=>{"Seller_name_1"=>"blacksmithproduc...       11.41     37
# 299999  {"seller"=>[{"Seller_name_1"=>"arstecnica", "S...        2.40     94
#
# [300000 rows x 17 columns]

# %%
df_expanded.columns
# Out:
# Index(['uniq_id', 'product_name', 'manufacturer', 'number_of_reviews',
#        'number_of_answered_questions', 'average_review_rating',
#        'amazon_category_and_sub_category',
#        'customers_who_bought_this_item_also_bought', 'description',
#        'product_information', 'product_description',
#        'items_customers_buy_after_viewing_this_item',
#        'customer_questions_and_answers', 'customer_reviews', 'sellers',
#        'price_rand', 'stock'],
#       dtype='object')
